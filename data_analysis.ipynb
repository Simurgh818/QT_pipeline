# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set_theme()

# %%
results_csv_path = r"C:\Users\sinad\OneDrive - Georgia Institute of Technology\CliffordandSameni\QT_results\QTdb_results\QT_wholedataset_results.csv"
df = pd.read_csv(results_csv_path)
df = df.dropna()
df.head()
# Out:
#    subject  record  channelNum  RR_mean_method_1  RR_median_method_1  \
# 0    1.0.0  sel100           1          0.793214               0.796
# 1    1.0.0  sel100           2          0.792515               0.796
# 8    1.0.0  sel114           1          0.952848               1.016
# 9    1.0.0  sel114           2          0.939979               1.016
# 10   1.0.0  sel116           1          0.759642               0.760
#
#     QTc1_median_method_1  QTc1_mean_method_1  QTc1_median_IQR_method_1  \
# 0               0.427073            0.429268                  0.422155
# 1               0.417237            0.421620                  0.422155
# 8               0.438995            0.437461                  0.448541
# 9               0.458241            0.450019                  0.448695
# 10              0.406422            0.412602                  0.411831
#
#     RR_median_method_2  RR_mean_method_2  ...  QTc1_median_method_2  \
# 0                0.796          0.793213  ...              0.413416
# 1                0.796          0.793213  ...              0.416416
# 8                1.051          1.041310  ...              0.429146
# 9                1.050          1.043710  ...              0.450300
# 10               0.759          0.761577  ...              0.392114
#
#     QTc1_median_SQI_method_2  QTc1_mean_jQRS_method_2  \
# 0                   0.426416                 0.415845
# 1                   0.417416                 0.420845
# 8                   0.429146                 0.433307
# 9                   0.439300                 0.457287
# 10                  0.392114                 0.396015
#
#     QTc1_jQRS_method_2_Gauss  QTc1_jQRS_method_2_Gauss_SQI  \
# 0                   0.415845                      0.415416
# 1                   0.423845                      0.423416
# 8                   0.438307                      0.437146
# 9                   0.431287                      0.430300
# 10                  0.394015                      0.394114
#
#     QTc1_median_IQR_Method_2  RR_median_human  RR_mean_human  \
# 0                   0.414916            0.800       0.797241
# 1                   0.414916            0.800       0.797241
# 8                   0.439646            0.960       5.367837
# 9                   0.439800            0.960       5.367837
# 10                  0.391114            0.788       5.444980
#
#     QTc1_median_human  QTc1_mean_human
# 0            0.428800         0.430133
# 1            0.428800         0.430133
# 8            0.460160         0.466240
# 9            0.460160         0.466240
# 10           0.400648         0.404168
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        channelNum  RR_mean_method_1  RR_median_method_1  QTc1_median_method_1  \
# count  150.000000        150.000000          150.000000            150.000000
# mean     1.513333          0.884326            0.892320              0.440144
# std      0.501497          0.166770            0.188907              0.030755
# min      1.000000          0.552528            0.512000              0.333613
# 25%      1.000000          0.764908            0.768000              0.417603
# 50%      2.000000          0.867725            0.868000              0.438237
# 75%      2.000000          1.000316            1.016000              0.462757
# max      2.000000          1.315123            1.352000              0.499061
#
#        QTc1_mean_method_1  QTc1_median_IQR_method_1  RR_median_method_2  \
# count          150.000000                150.000000          150.000000
# mean             0.439223                  0.441723            0.917153
# std              0.030059                  0.026877            0.212716
# min              0.335232                  0.359639            0.451000
# 25%              0.420387                  0.420600            0.769000
# 50%              0.437630                  0.443853            0.886250
# 75%              0.461039                  0.461843            1.059000
# max              0.492376                  0.494604            1.359000
#
#        RR_mean_method_2  RR_jQRS_method_2  QTc1_median_method_2  \
# count        150.000000        150.000000            150.000000
# mean           0.916160          0.918800              0.414305
# std            0.211183          0.212254              0.027655
# min            0.447438          0.447493              0.348922
# 25%            0.764335          0.770506              0.393721
# 50%            0.888807          0.889686              0.412381
# 75%            1.054777          1.054770              0.432828
# max            1.362284          1.361995              0.492422
#
#        QTc1_median_SQI_method_2  QTc1_mean_jQRS_method_2  \
# count                150.000000               150.000000
# mean                   0.415558                 0.416385
# std                    0.025588                 0.028639
# min                    0.350922                 0.350477
# 25%                    0.394902                 0.395144
# 50%                    0.414633                 0.413280
# 75%                    0.435663                 0.435411
# max                    0.489714                 0.496652
#
#        QTc1_jQRS_method_2_Gauss  QTc1_jQRS_method_2_Gauss_SQI  \
# count                150.000000                    150.000000
# mean                   0.414872                      0.415258
# std                    0.027924                      0.028156
# min                    0.311961                      0.311868
# 25%                    0.395863                      0.396908
# 50%                    0.413081                      0.412394
# 75%                    0.435376                      0.436037
# max                    0.486148                      0.484751
#
#        QTc1_median_IQR_Method_2  RR_median_human  RR_mean_human  \
# count                150.000000       150.000000     150.000000
# mean                   0.415218         0.933693       1.950402
# std                    0.025460         0.227251       2.255749
# min                    0.363390         0.488000       0.547172
# 25%                    0.394442         0.791000       0.815586
# 50%                    0.413052         0.900000       1.025517
# 75%                    0.428740         1.082000       1.270207
# max                    0.498251         1.540000       9.469867
#
#        QTc1_median_human  QTc1_mean_human
# count         150.000000       150.000000
# mean            0.419131         0.419956
# std             0.032553         0.032193
# min             0.328840         0.333107
# 25%             0.399720         0.400595
# 50%             0.418960         0.420579
# 75%             0.437914         0.440433
# max             0.492272         0.493716

# %%
QTc1_median = df.loc[:,['channelNum', 'QTc1_median_human', 'QTc1_median_method_1','QTc1_median_method_2']]
QTc1_median
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 0             1           0.428800              0.427073              0.413416
# 1             2           0.428800              0.417237              0.416416
# 8             1           0.460160              0.438995              0.429146
# 9             2           0.460160              0.458241              0.450300
# 10            1           0.400648              0.406422              0.392114
# ..          ...                ...                   ...                   ...
# 205           2           0.476952              0.406210              0.477646
# 206           1           0.460112              0.458020              0.443660
# 207           2           0.460112              0.458570              0.449660
# 208           1           0.399720              0.402291              0.382954
# 209           2           0.399720              0.483610              0.401954
#
# [150 rows x 4 columns]

# %%
QTc1_median_lead1 = QTc1_median[QTc1_median.loc[:, 'channelNum']==1]
QTc1_median_lead1
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 0             1           0.428800              0.427073              0.413416
# 8             1           0.460160              0.438995              0.429146
# 10            1           0.400648              0.406422              0.392114
# 12            1           0.422128              0.433098              0.399050
# 14            1           0.414264              0.427203              0.404200
# ..          ...                ...                   ...                   ...
# 200           1           0.419744              0.432899              0.416288
# 202           1           0.450200              0.434385              0.390574
# 204           1           0.476952              0.403266              0.462800
# 206           1           0.460112              0.458020              0.443660
# 208           1           0.399720              0.402291              0.382954
#
# [73 rows x 4 columns]

# %%
QTc1_median_lead1 = QTc1_median_lead1.drop('channelNum', axis=1)

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax = sns.boxplot(data=QTc1_median_lead1).set(title='Lead 1 Median QTlc Interval')
ax = sns.swarmplot(data=QTc1_median_lead1, color=".25")
# ax.fig.suptitle('Lead 1 Median QTlc Interval')

# %%
QTc1_median_lead1.describe().round(decimals=4)
# Out:
#        QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# count            73.0000               73.0000               73.0000
# mean              0.4180                0.4375                0.4148
# std               0.0316                0.0304                0.0258
# min               0.3288                0.3697                0.3679
# 25%               0.3991                0.4164                0.3952
# 50%               0.4182                0.4354                0.4134
# 75%               0.4372                0.4586                0.4319
# max               0.4858                0.4991                0.4924

# %%
QTc1_median_lead2 = QTc1_median[QTc1_median.loc[:, 'channelNum']==2]
QTc1_median_lead2
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 1             2           0.428800              0.417237              0.416416
# 9             2           0.460160              0.458241              0.450300
# 11            2           0.400648              0.417086              0.389960
# 13            2           0.422128              0.428275              0.390050
# 15            2           0.414264              0.434655              0.414200
# ..          ...                ...                   ...                   ...
# 201           2           0.419744              0.497879              0.413750
# 203           2           0.450200              0.461957              0.443574
# 205           2           0.476952              0.406210              0.477646
# 207           2           0.460112              0.458570              0.449660
# 209           2           0.399720              0.483610              0.401954
#
# [77 rows x 4 columns]

# %%
QTc1_median_lead2 = QTc1_median_lead2.drop('channelNum', axis=1)
QTc1_median_lead2
# Out:
#      QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 1             0.428800              0.417237              0.416416
# 9             0.460160              0.458241              0.450300
# 11            0.400648              0.417086              0.389960
# 13            0.422128              0.428275              0.390050
# 15            0.414264              0.434655              0.414200
# ..                 ...                   ...                   ...
# 201           0.419744              0.497879              0.413750
# 203           0.450200              0.461957              0.443574
# 205           0.476952              0.406210              0.477646
# 207           0.460112              0.458570              0.449660
# 209           0.399720              0.483610              0.401954
#
# [77 rows x 3 columns]

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax2 = sns.boxplot(data=QTc1_median_lead2).set(title='Lead 2 Median QTlc Interval')
ax2 = sns.swarmplot(data=QTc1_median_lead2, color=".25")

# %%
QTc1_median_lead2.describe().round(decimals=4)
# Out:
#        QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# count            77.0000               77.0000               77.0000
# mean              0.4202                0.4426                0.4138
# std               0.0336                0.0311                0.0295
# min               0.3288                0.3336                0.3489
# 25%               0.4003                0.4199                0.3919
# 50%               0.4197                0.4442                0.4097
# 75%               0.4381                0.4693                0.4330
# max               0.4923                0.4979                0.4898

# %%
RR_selection = ['record','channelNum','RR_median_human','RR_median_method_1','RR_median_method_2']
RR_median = df.loc[:,RR_selection]
RR_median
# Out:
#        record  channelNum  RR_median_human  RR_median_method_1  \
# 0      sel100           1            0.800               0.796
# 1      sel100           2            0.800               0.796
# 8      sel114           1            0.960               1.016
# 9      sel114           2            0.960               1.016
# 10     sel116           1            0.788               0.760
# ..        ...         ...              ...                 ...
# 205  sele0609           2            0.812               0.800
# 206  sele0612           1            1.272               1.208
# 207  sele0612           2            1.272               1.208
# 208  sele0704           1            0.820               0.800
# 209  sele0704           2            0.820               0.800
#
#      RR_median_method_2
# 0                 0.796
# 1                 0.796
# 8                 1.051
# 9                 1.050
# 10                0.759
# ..                  ...
# 205               0.801
# 206               1.210
# 207               1.210
# 208               0.799
# 209               0.799
#
# [150 rows x 5 columns]

# %%
RR_median_for_box = RR_median.drop(['record','channelNum'], axis=1)
RR_median_for_box
# Out:
#      RR_median_human  RR_median_method_1  RR_median_method_2
# 0              0.800               0.796               0.796
# 1              0.800               0.796               0.796
# 8              0.960               1.016               1.051
# 9              0.960               1.016               1.050
# 10             0.788               0.760               0.759
# ..               ...                 ...                 ...
# 205            0.812               0.800               0.801
# 206            1.272               1.208               1.210
# 207            1.272               1.208               1.210
# 208            0.820               0.800               0.799
# 209            0.820               0.800               0.799
#
# [150 rows x 3 columns]

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax2 = sns.boxplot(data=RR_median_for_box).set(title='Median RR interval comparisons')
ax2 = sns.swarmplot(data=RR_median_for_box, color=".25")

# %%
RR_median_for_box.describe().round(decimals=4)
# Out:
#        RR_median_human  RR_median_method_1  RR_median_method_2
# count         150.0000            150.0000            150.0000
# mean            0.9337              0.8923              0.9172
# std             0.2273              0.1889              0.2127
# min             0.4880              0.5120              0.4510
# 25%             0.7910              0.7680              0.7690
# 50%             0.9000              0.8680              0.8862
# 75%             1.0820              1.0160              1.0590
# max             1.5400              1.3520              1.3590

# %% [markdown]
# #### Method 2 Median RR is close to human in it's median value (50%), mean, standard deviation

# %%
from sklearn.metrics import mean_squared_error
# QT.RMSE_method_1 = sqrt(nanmean((QT.QTc1_median_IQR_Method_1-QT.QTc1_median_human).^2));

RR_median_Method_1 = df.loc[:,['RR_median_method_1']]
RR_median_human =  df.loc[:,['RR_median_human']]
RR_median_Method_2 = df.loc[:,['RR_median_method_2']]
# RMSE_RR_median_method_1 = np.sqrt(np.nanmean(np.square(QTc1_median_IQR_Method_1 - QTc1_median_human)))
RMSE_RR_median_method_1 = mean_squared_error(RR_median_human, RR_median_Method_1, squared=False)
RMSE_RR_median_method_2 = mean_squared_error(RR_median_human, RR_median_Method_2, squared=False)
print('RMSE for Method 1 RR: ', np.round(RMSE_RR_median_method_1, 4), 'RMSE for Method 2 RR: ', np.round(RMSE_RR_median_method_2, 4))
# QTc1_median_human
# Out:
# RMSE for Method 1 RR:  0.1519 RMSE for Method 2 RR:  0.0697

# %%
RR_selection_mean = ['record','channelNum','RR_mean_human','RR_mean_method_1','RR_jQRS_method_2']
RR_mean = df.loc[:,RR_selection_mean]
RR_mean
# Out:
#        record  channelNum  RR_mean_human  RR_mean_method_1  RR_jQRS_method_2
# 0      sel100           1       0.797241          0.793214          0.793213
# 1      sel100           2       0.797241          0.792515          0.793213
# 8      sel114           1       5.367837          0.952848          1.043463
# 9      sel114           2       5.367837          0.939979          1.043590
# 10     sel116           1       5.444980          0.759642          0.759640
# ..        ...         ...            ...               ...               ...
# 205  sele0609           2       0.815586          0.798973          0.803971
# 206  sele0612           1       1.268966          1.198981          1.198981
# 207  sele0612           2       1.268966          1.198971          1.198971
# 208  sele0704           1       0.813655          0.822752          0.829580
# 209  sele0704           2       0.813655          0.822752          0.823506
#
# [150 rows x 5 columns]

# %%
RR_mean_for_box = RR_mean.drop(['record','channelNum'], axis=1)
RR_mean_for_box
# Out:
#      RR_mean_human  RR_mean_method_1  RR_jQRS_method_2
# 0         0.797241          0.793214          0.793213
# 1         0.797241          0.792515          0.793213
# 8         5.367837          0.952848          1.043463
# 9         5.367837          0.939979          1.043590
# 10        5.444980          0.759642          0.759640
# ..             ...               ...               ...
# 205       0.815586          0.798973          0.803971
# 206       1.268966          1.198981          1.198981
# 207       1.268966          1.198971          1.198971
# 208       0.813655          0.822752          0.829580
# 209       0.813655          0.822752          0.823506
#
# [150 rows x 3 columns]

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax2 = sns.boxplot(data=RR_mean_for_box).set(title='Mean RR interval comparisons')
ax2 = sns.swarmplot(data=RR_mean_for_box, color=".25")
# Out:
# C:\Users\sinad\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sinad\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sinad\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
RR_mean_for_box.describe().round(decimals=4)
# Out:
#        RR_mean_human  RR_mean_method_1  RR_jQRS_method_2
# count       150.0000          150.0000          150.0000
# mean          1.9504            0.8843            0.9188
# std           2.2557            0.1668            0.2123
# min           0.5472            0.5525            0.4475
# 25%           0.8156            0.7649            0.7705
# 50%           1.0255            0.8677            0.8897
# 75%           1.2702            1.0003            1.0548
# max           9.4699            1.3151            1.3620
