# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set_theme()

# %%
results_csv_path = r"C:\Users\sinad\OneDrive - Georgia Institute of Technology\CliffordandSameni\QT_results\QTdb_results\QT_wholedataset_results.csv"
df = pd.read_csv(results_csv_path)
df = df.dropna()
df.head()
# Out:
#    subject  record  channelNum  RR_mean_method_1  RR_median_method_1  \
# 0    1.0.0  sel100           1          0.793214               0.796
# 1    1.0.0  sel100           2          0.792515               0.796
# 8    1.0.0  sel114           1          0.952848               1.016
# 9    1.0.0  sel114           2          0.939979               1.016
# 10   1.0.0  sel116           1          0.759642               0.760
#
#     QTc1_median_method_1  QTc1_mean_method_1  QTc1_median_IQR_method_1  \
# 0               0.427073            0.429268                  0.422155
# 1               0.417237            0.421728                  0.422155
# 8               0.444385            0.451084                  0.453931
# 9               0.463477            0.465994                  0.453931
# 10              0.406268            0.412900                  0.411677
#
#     RR_median_method_2  RR_jQRS_method_2  QTc1_median_method_2  \
# 0                0.796          0.793213              0.413416
# 1                0.796          0.793213              0.416416
# 8                1.051          1.043463              0.429146
# 9                1.050          1.043590              0.450300
# 10               0.759          0.759640              0.392114
#
#     QTc1_median_SQI_method_2  QTc1_mean_jQRS_method_2  \
# 0                   0.426416                 0.415845
# 1                   0.417416                 0.420845
# 8                   0.429146                 0.433307
# 9                   0.439300                 0.457287
# 10                  0.392114                 0.396015
#
#     QTc1_jQRS_method_2_Gauss  QTc1_jQRS_method_2_Gauss_SQI  \
# 0                   0.415845                      0.415416
# 1                   0.423845                      0.423416
# 8                   0.438307                      0.437146
# 9                   0.431287                      0.430300
# 10                  0.394015                      0.394114
#
#     QTc1_median_IQR_Method_2  RR_median_human  RR_mean_human  \
# 0                   0.414916            0.800       0.797241
# 1                   0.414916            0.800       0.797241
# 8                   0.439646            0.960       5.367837
# 9                   0.439800            0.960       5.367837
# 10                  0.391114            0.788       5.444980
#
#     QTc1_median_human  QTc1_mean_human
# 0            0.428800         0.430133
# 1            0.428800         0.430133
# 8            0.460160         0.466240
# 9            0.460160         0.466240
# 10           0.400648         0.404168

# %%
df.describe()
# Out:
#        channelNum  RR_mean_method_1  RR_median_method_1  QTc1_median_method_1  \
# count  144.000000        144.000000          144.000000            144.000000
# mean     1.520833          0.886433            0.896472              0.441530
# std      0.501309          0.169274            0.188644              0.029456
# min      1.000000          0.552528            0.512000              0.337155
# 25%      1.000000          0.767295            0.777000              0.420798
# 50%      2.000000          0.867725            0.871000              0.442553
# 75%      2.000000          1.003134            1.029000              0.463502
# max      2.000000          1.315123            1.352000              0.499292
#
#        QTc1_mean_method_1  QTc1_median_IQR_method_1  RR_median_method_2  \
# count          144.000000                144.000000          144.000000
# mean             0.442423                  0.443166            0.905049
# std              0.027131                  0.025818            0.206552
# min              0.356821                  0.363181            0.451000
# 25%              0.423476                  0.421880            0.759750
# 50%              0.442339                  0.444271            0.876750
# 75%              0.461421                  0.461080            1.053250
# max              0.497235                  0.494758            1.359000
#
#        RR_jQRS_method_2  QTc1_median_method_2  QTc1_median_SQI_method_2  \
# count        144.000000            144.000000                144.000000
# mean           0.905947              0.414192                  0.415261
# std            0.204369              0.027940                  0.025664
# min            0.447493              0.348922                  0.350922
# 25%            0.767128              0.393595                  0.394800
# 50%            0.876107              0.410702                  0.413628
# 75%            1.048331              0.433356                  0.434706
# max            1.357396              0.492422                  0.489714
#
#        QTc1_mean_jQRS_method_2  QTc1_jQRS_method_2_Gauss  \
# count               144.000000                144.000000
# mean                  0.415908                  0.414512
# std                   0.028234                  0.027548
# min                   0.350477                  0.311961
# 25%                   0.395414                  0.395943
# 50%                   0.412776                  0.412467
# 75%                   0.434935                  0.434722
# max                   0.496652                  0.486148
#
#        QTc1_jQRS_method_2_Gauss_SQI  QTc1_median_IQR_Method_2  \
# count                    144.000000                144.000000
# mean                       0.414629                  0.415008
# std                        0.027847                  0.025691
# min                        0.311868                  0.363390
# 25%                        0.396655                  0.394367
# 50%                        0.411914                  0.412474
# 75%                        0.435816                  0.429938
# max                        0.484751                  0.498251
#
#        RR_median_human  RR_mean_human  QTc1_median_human  QTc1_mean_human
# count       144.000000     144.000000         144.000000       144.000000
# mean          0.920375       1.866708           0.418109         0.418949
# std           0.219734       2.118392           0.032267         0.031943
# min           0.488000       0.547172           0.328840         0.333107
# 25%           0.785000       0.813655           0.399104         0.400253
# 50%           0.884000       0.989931           0.417328         0.417509
# 75%           1.070000       1.243207           0.437470         0.439183
# max           1.540000       8.840933           0.492272         0.493716

# %%
QTc1_median = df.loc[:,['channelNum', 'QTc1_median_human', 'QTc1_median_method_1','QTc1_median_method_2']]
QTc1_median
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 0             1           0.428800              0.427073              0.413416
# 1             2           0.428800              0.417237              0.416416
# 8             1           0.460160              0.444385              0.429146
# 9             2           0.460160              0.463477              0.450300
# 10            1           0.400648              0.406268              0.392114
# ..          ...                ...                   ...                   ...
# 205           2           0.476952              0.406364              0.477646
# 206           1           0.460112              0.458328              0.443660
# 207           2           0.460112              0.458878              0.449660
# 208           1           0.399720              0.402137              0.382954
# 209           2           0.399720              0.483456              0.401954
#
# [144 rows x 4 columns]

# %%
QTc1_median_lead1 = QTc1_median[QTc1_median.loc[:, 'channelNum']==1]
QTc1_median_lead1
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 0             1           0.428800              0.427073              0.413416
# 8             1           0.460160              0.444385              0.429146
# 10            1           0.400648              0.406268              0.392114
# 12            1           0.422128              0.432944              0.399050
# 14            1           0.414264              0.427203              0.404200
# ..          ...                ...                   ...                   ...
# 200           1           0.419744              0.432899              0.416288
# 202           1           0.450200              0.434539              0.390574
# 204           1           0.476952              0.403882              0.462800
# 206           1           0.460112              0.458328              0.443660
# 208           1           0.399720              0.402137              0.382954
#
# [69 rows x 4 columns]

# %%
QTc1_median_lead1 = QTc1_median_lead1.drop('channelNum', axis=1)

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax = sns.boxplot(data=QTc1_median_lead1).set(title='Lead 1 Median QTlc Interval')
ax = sns.swarmplot(data=QTc1_median_lead1, color=".25")
# ax.fig.suptitle('Lead 1 Median QTlc Interval')

# %%
QTc1_median_lead1.describe().round(decimals=4)
# Out:
#        QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# count            69.0000               69.0000               69.0000
# mean              0.4157                0.4381                0.4142
# std               0.0304                0.0284                0.0263
# min               0.3288                0.3697                0.3679
# 25%               0.3985                0.4172                0.3945
# 50%               0.4143                0.4357                0.4120
# 75%               0.4360                0.4585                0.4319
# max               0.4770                0.4993                0.4924

# %%
QTc1_median_lead2 = QTc1_median[QTc1_median.loc[:, 'channelNum']==2]
QTc1_median_lead2
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 1             2           0.428800              0.417237              0.416416
# 9             2           0.460160              0.463477              0.450300
# 11            2           0.400648              0.417086              0.389960
# 13            2           0.422128              0.428121              0.390050
# 15            2           0.414264              0.444511              0.414200
# ..          ...                ...                   ...                   ...
# 201           2           0.419744              0.497417              0.413750
# 203           2           0.450200              0.462111              0.443574
# 205           2           0.476952              0.406364              0.477646
# 207           2           0.460112              0.458878              0.449660
# 209           2           0.399720              0.483456              0.401954
#
# [75 rows x 4 columns]

# %%
QTc1_median_lead2 = QTc1_median_lead2.drop('channelNum', axis=1)
QTc1_median_lead2
# Out:
#      QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 1             0.428800              0.417237              0.416416
# 9             0.460160              0.463477              0.450300
# 11            0.400648              0.417086              0.389960
# 13            0.422128              0.428121              0.390050
# 15            0.414264              0.444511              0.414200
# ..                 ...                   ...                   ...
# 201           0.419744              0.497417              0.413750
# 203           0.450200              0.462111              0.443574
# 205           0.476952              0.406364              0.477646
# 207           0.460112              0.458878              0.449660
# 209           0.399720              0.483456              0.401954
#
# [75 rows x 3 columns]

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax2 = sns.boxplot(data=QTc1_median_lead2).set(title='Lead 2 Median QTlc Interval')
ax2 = sns.swarmplot(data=QTc1_median_lead2, color=".25")

# %%
QTc1_median_lead2.describe().round(decimals=4)
# Out:
#        QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# count            75.0000               75.0000               75.0000
# mean              0.4203                0.4447                0.4142
# std               0.0340                0.0303                0.0295
# min               0.3288                0.3372                0.3489
# 25%               0.4000                0.4246                0.3925
# 50%               0.4197                0.4458                0.4097
# 75%               0.4391                0.4691                0.4337
# max               0.4923                0.4974                0.4898

# %%
RR_selection = ['record','channelNum','RR_median_human','RR_median_method_1','RR_median_method_2']
RR_median = df.loc[:,RR_selection]
RR_median
# Out:
#        record  channelNum  RR_median_human  RR_median_method_1  \
# 0      sel100           1            0.800               0.796
# 1      sel100           2            0.800               0.796
# 8      sel114           1            0.960               1.016
# 9      sel114           2            0.960               1.016
# 10     sel116           1            0.788               0.760
# ..        ...         ...              ...                 ...
# 205  sele0609           2            0.812               0.800
# 206  sele0612           1            1.272               1.208
# 207  sele0612           2            1.272               1.208
# 208  sele0704           1            0.820               0.800
# 209  sele0704           2            0.820               0.800
#
#      RR_median_method_2
# 0                 0.796
# 1                 0.796
# 8                 1.051
# 9                 1.050
# 10                0.759
# ..                  ...
# 205               0.801
# 206               1.210
# 207               1.210
# 208               0.799
# 209               0.799
#
# [144 rows x 5 columns]

# %%
RR_median_for_box = RR_median.drop(['record','channelNum'], axis=1)
RR_median_for_box
# Out:
#      RR_median_human  RR_median_method_1  RR_median_method_2
# 0              0.800               0.796               0.796
# 1              0.800               0.796               0.796
# 8              0.960               1.016               1.051
# 9              0.960               1.016               1.050
# 10             0.788               0.760               0.759
# ..               ...                 ...                 ...
# 205            0.812               0.800               0.801
# 206            1.272               1.208               1.210
# 207            1.272               1.208               1.210
# 208            0.820               0.800               0.799
# 209            0.820               0.800               0.799
#
# [144 rows x 3 columns]

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax2 = sns.boxplot(data=RR_median_for_box).set(title='Median RR interval comparisons')
ax2 = sns.swarmplot(data=RR_median_for_box, color=".25")

# %%
RR_median_for_box.describe().round(decimals=4)
# Out:
#        RR_median_human  RR_median_method_1  RR_median_method_2
# count         144.0000            144.0000            144.0000
# mean            0.9204              0.8965              0.9050
# std             0.2197              0.1886              0.2066
# min             0.4880              0.5120              0.4510
# 25%             0.7850              0.7770              0.7598
# 50%             0.8840              0.8710              0.8768
# 75%             1.0700              1.0290              1.0532
# max             1.5400              1.3520              1.3590

# %% [markdown]
# #### Method 2 Median RR is close to human in it's median value (50%), mean, standard deviation

# %%
from sklearn.metrics import mean_squared_error
# QT.RMSE_method_1 = sqrt(nanmean((QT.QTc1_median_IQR_Method_1-QT.QTc1_median_human).^2));

RR_median_Method_1 = df.loc[:,['RR_median_method_1']]
RR_median_human =  df.loc[:,['RR_median_human']]
RR_median_Method_2 = df.loc[:,['RR_median_method_2']]
# RMSE_RR_median_method_1 = np.sqrt(np.nanmean(np.square(QTc1_median_IQR_Method_1 - QTc1_median_human)))
RMSE_RR_median_method_1 = mean_squared_error(RR_median_human, RR_median_Method_1, squared=False)
RMSE_RR_median_method_2 = mean_squared_error(RR_median_human, RR_median_Method_2, squared=False)
print('RMSE for Method 1 RR: ', np.round(RMSE_RR_median_method_1, 4), 'RMSE for Method 2 RR: ', np.round(RMSE_RR_median_method_2, 4))
# QTc1_median_human
# Out:
# RMSE for Method 1 RR:  0.1047 RMSE for Method 2 RR:  0.0701

# %%
RR_selection_mean = ['record','channelNum','RR_mean_human','RR_mean_method_1','RR_jQRS_method_2']
RR_mean = df.loc[:,RR_selection_mean]
RR_mean
# Out:
#        record  channelNum  RR_mean_human  RR_mean_method_1  RR_jQRS_method_2
# 0    sel100_Q           1       0.797241          0.793214          0.793213
# 1    sel100_Q           2       0.797241          0.792515          0.793213
# 2    sel102_Q           1       3.516143          0.827124          0.827125
# 3    sel102_Q           2       3.516143          0.827117          0.827121
# 4    sel103_Q           1       0.856828          0.858048          0.858048
# ..        ...         ...            ...               ...               ...
# 205  sele0609           2       0.815586          0.798973          0.803971
# 206  sele0612           1       1.268966          1.198981          1.198981
# 207  sele0612           2       1.268966          1.198971          1.198971
# 208  sele0704           1       0.813655          0.822752          0.829580
# 209  sele0704           2       0.813655          0.822752          0.823506
#
# [210 rows x 5 columns]

# %%
RR_mean_for_box = RR_mean.drop(['record','channelNum'], axis=1)
RR_mean_for_box
# Out:
#      RR_mean_human  RR_mean_method_1  RR_jQRS_method_2
# 0         0.797241          0.793214          0.793213
# 1         0.797241          0.792515          0.793213
# 2         3.516143          0.827124          0.827125
# 3         3.516143          0.827117          0.827121
# 4         0.856828          0.858048          0.858048
# ..             ...               ...               ...
# 205       0.815586          0.798973          0.803971
# 206       1.268966          1.198981          1.198981
# 207       1.268966          1.198971          1.198971
# 208       0.813655          0.822752          0.829580
# 209       0.813655          0.822752          0.823506
#
# [210 rows x 3 columns]

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax2 = sns.boxplot(data=RR_mean_for_box).set(title='Mean RR interval comparisons')
ax2 = sns.swarmplot(data=RR_mean_for_box, color=".25")
# Out:
# C:\Users\sinad\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sinad\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 62.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sinad\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
RR_mean_for_box.describe().round(decimals=4)
# Out:
#        RR_mean_human  RR_mean_method_1  RR_jQRS_method_2
# count       206.0000          210.0000          210.0000
# mean          1.9368            0.8547            0.9127
# std           2.1181            0.1635            0.2387
# min           0.4701            0.5180            0.4475
# 25%           0.8141            0.7476            0.7542
# 50%           1.0283            0.8414            0.8723
# 75%           1.6097            0.9728            1.0460
# max           9.4699            1.3151            1.7384
