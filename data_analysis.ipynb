# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set_theme()

# %%
results_csv_path = r"C:\Users\sinad\OneDrive - Georgia Institute of Technology\CliffordandSameni\QT_results\QTdb_results\QT_wholedataset_results.csv"
df = pd.read_csv(results_csv_path)
df.head()
# Out:
#   subject    record  channelNum  RR_mean_method_1  RR_median_method_1  \
# 0   1.0.0  sel100_Q           1          0.793214               0.796
# 1   1.0.0  sel100_Q           2          0.792515               0.796
# 2   1.0.0  sel102_Q           1          0.827124               0.828
# 3   1.0.0  sel102_Q           2          0.827117               0.828
# 4   1.0.0  sel103_Q           1          0.858048               0.856
#
#    QTc1_median_method_1  QTc1_mean_method_1  QTc1_median_IQR_method_1  \
# 0              0.427073            0.429268                  0.422155
# 1              0.417237            0.421728                  0.422155
# 2              0.436813            0.444637                  0.469835
# 3                   NaN                 NaN                  0.469835
# 4              0.439406            0.440852                  0.469908
#
#    RR_median_method_2  RR_jQRS_method_2  QTc1_median_method_2  \
# 0               0.796          0.793213              0.413416
# 1               0.796          0.793213              0.416416
# 2               0.827          0.827125                   NaN
# 3               0.828          0.827121              0.442488
# 4               0.858          0.858048              0.416868
#
#    QTc1_median_SQI_method_2  QTc1_mean_jQRS_method_2  \
# 0                  0.426416                 0.415845
# 1                  0.417416                 0.420845
# 2                       NaN                      NaN
# 3                  0.452488                 0.445623
# 4                  0.417868                 0.419861
#
#    QTc1_jQRS_method_2_Gauss  QTc1_jQRS_method_2_Gauss_SQI  \
# 0                  0.415845                      0.415416
# 1                  0.423845                      0.423416
# 2                       NaN                           NaN
# 3                  0.444623                      0.444488
# 4                  0.420861                      0.420868
#
#    QTc1_median_IQR_Method_2  RR_median_human  RR_mean_human  \
# 0                  0.414916            0.800       0.797241
# 1                  0.414916            0.800       0.797241
# 2                  0.483642            0.858       3.516143
# 3                  0.483488            0.858       3.516143
# 4                       NaN            0.852       0.856828
#
#    QTc1_median_human  QTc1_mean_human
# 0           0.428800         0.430133
# 1           0.428800         0.430133
# 2           0.489868         0.492315
# 3           0.489868         0.492315
# 4           0.430792         0.430925

# %%
df.describe()
# Out:
#        channelNum  RR_mean_method_1  RR_median_method_1  QTc1_median_method_1  \
# count  210.000000        210.000000          210.000000            186.000000
# mean     1.500000          0.854724            0.852276              0.441791
# std      0.501195          0.163518            0.187668              0.031187
# min      1.000000          0.518027            0.468000              0.337155
# 25%      1.000000          0.747625            0.721000              0.418852
# 50%      1.500000          0.841438            0.842000              0.441435
# 75%      2.000000          0.972808            1.000000              0.467976
# max      2.000000          1.315123            1.352000              0.499794
#
#        QTc1_mean_method_1  QTc1_median_IQR_method_1  RR_median_method_2  \
# count          198.000000                195.000000          210.000000
# mean             0.444216                  0.445164            0.897674
# std              0.029636                  0.027101            0.230161
# min              0.356821                  0.363181            0.451000
# 25%              0.424491                  0.423479            0.741000
# 50%              0.444405                  0.446908            0.869000
# 75%              0.464388                  0.469564            1.042000
# max              0.499642                  0.494758            1.704000
#
#        RR_jQRS_method_2  QTc1_median_method_2  QTc1_median_SQI_method_2  \
# count        210.000000            184.000000                189.000000
# mean           0.912729              0.418776                  0.420054
# std            0.238653              0.030702                  0.029370
# min            0.447493              0.348922                  0.348366
# 25%            0.754215              0.395037                  0.396842
# 50%            0.872289              0.416544                  0.417416
# 75%            1.046035              0.439340                  0.439502
# max            1.738443              0.499617                  0.498617
#
#        QTc1_mean_jQRS_method_2  QTc1_jQRS_method_2_Gauss  \
# count               179.000000                182.000000
# mean                  0.419659                  0.418038
# std                   0.030175                  0.030362
# min                   0.350477                  0.311961
# 25%                   0.396245                  0.397033
# 50%                   0.416364                  0.415161
# 75%                   0.438126                  0.439836
# max                   0.496652                  0.499206
#
#        QTc1_jQRS_method_2_Gauss_SQI  QTc1_median_IQR_Method_2  \
# count                    182.000000                181.000000
# mean                       0.419209                  0.419710
# std                        0.030875                  0.028942
# min                        0.311868                  0.363390
# 25%                        0.398115                  0.395824
# 50%                        0.417008                  0.415537
# 75%                        0.440067                  0.438392
# max                        0.499328                  0.498251
#
#        RR_median_human  RR_mean_human  QTc1_median_human  QTc1_mean_human
# count       206.000000     206.000000         186.000000       186.000000
# mean          0.927689       1.936805           0.421440         0.422337
# std           0.253241       2.118117           0.034737         0.034641
# min           0.468000       0.470069           0.328840         0.333107
# 25%           0.747500       0.814138           0.399720         0.400595
# 50%           0.868000       1.028276           0.420496         0.422661
# 75%           1.074000       1.609700           0.441872         0.443373
# max           1.692000       9.469867           0.492272         0.493716

# %%
QTc1_median = df.loc[:,['channelNum', 'QTc1_median_human', 'QTc1_median_method_1','QTc1_median_method_2']]
QTc1_median
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 0             1           0.428800              0.427073              0.413416
# 1             2           0.428800              0.417237              0.416416
# 2             1           0.489868              0.436813                   NaN
# 3             2           0.489868                   NaN              0.442488
# 4             1           0.430792              0.439406              0.416868
# ..          ...                ...                   ...                   ...
# 205           2           0.476952              0.406364              0.477646
# 206           1           0.460112              0.458328              0.443660
# 207           2           0.460112              0.458878              0.449660
# 208           1           0.399720              0.402137              0.382954
# 209           2           0.399720              0.483456              0.401954
#
# [210 rows x 4 columns]

# %%
QTc1_median_lead1 = QTc1_median[QTc1_median.loc[:, 'channelNum']==1]
QTc1_median_lead1
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 0             1           0.428800              0.427073              0.413416
# 2             1           0.489868              0.436813                   NaN
# 4             1           0.430792              0.439406              0.416868
# 6             1                NaN              0.469521                   NaN
# 8             1           0.460160              0.444385              0.429146
# ..          ...                ...                   ...                   ...
# 200           1           0.419744              0.432899              0.416288
# 202           1           0.450200              0.434539              0.390574
# 204           1           0.476952              0.403882              0.462800
# 206           1           0.460112              0.458328              0.443660
# 208           1           0.399720              0.402137              0.382954
#
# [105 rows x 4 columns]

# %%
QTc1_median_lead1 = QTc1_median_lead1.drop('channelNum', axis=1)

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax = sns.boxplot(data=QTc1_median_lead1)
ax = sns.swarmplot(data=QTc1_median_lead1, color=".25")

# %%
QTc1_median_lead1.describe().round(decimals=4)
# Out:
#        channelNum  QTc1_median_human  QTc1_median_method_1  \
# count       105.0            93.0000               90.0000
# mean          1.0             0.4214                0.4388
# std           0.0             0.0348                0.0303
# min           1.0             0.3288                0.3670
# 25%           1.0             0.3997                0.4169
# 50%           1.0             0.4205                0.4371
# 75%           1.0             0.4419                0.4620
# max           1.0             0.4923                0.4993
#
#        QTc1_median_method_2
# count               91.0000
# mean                 0.4191
# std                  0.0289
# min                  0.3679
# 25%                  0.3957
# 50%                  0.4167
# 75%                  0.4381
# max                  0.4996

# %%
QTc1_median_lead2 = QTc1_median[QTc1_median.loc[:, 'channelNum']==2]
QTc1_median_lead2
# Out:
#      channelNum  QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 1             2           0.428800              0.417237              0.416416
# 3             2           0.489868                   NaN              0.442488
# 5             2           0.430792              0.499794              0.416868
# 7             2                NaN              0.379897                   NaN
# 9             2           0.460160              0.463477              0.450300
# ..          ...                ...                   ...                   ...
# 201           2           0.419744              0.497417              0.413750
# 203           2           0.450200              0.462111              0.443574
# 205           2           0.476952              0.406364              0.477646
# 207           2           0.460112              0.458878              0.449660
# 209           2           0.399720              0.483456              0.401954
#
# [105 rows x 4 columns]

# %%
QTc1_median_lead2 = QTc1_median_lead2.drop('channelNum', axis=1)
QTc1_median_lead2
# Out:
#      QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# 1             0.428800              0.417237              0.416416
# 3             0.489868                   NaN              0.442488
# 5             0.430792              0.499794              0.416868
# 7                  NaN              0.379897                   NaN
# 9             0.460160              0.463477              0.450300
# ..                 ...                   ...                   ...
# 201           0.419744              0.497417              0.413750
# 203           0.450200              0.462111              0.443574
# 205           0.476952              0.406364              0.477646
# 207           0.460112              0.458878              0.449660
# 209           0.399720              0.483456              0.401954
#
# [105 rows x 3 columns]

# %%
sns.set(rc = {'figure.figsize':(8,4)})
ax2 = sns.boxplot(data=QTc1_median_lead2)
ax2 = sns.swarmplot(data=QTc1_median_lead2, color=".25")

# %%
QTc1_median_lead2.describe().round(decimals=4)
# Out:
#        QTc1_median_human  QTc1_median_method_1  QTc1_median_method_2
# count            93.0000               96.0000               93.0000
# mean              0.4214                0.4446                0.4185
# std               0.0348                0.0319                0.0325
# min               0.3288                0.3372                0.3489
# 25%               0.3997                0.4223                0.3934
# 50%               0.4205                0.4450                0.4164
# 75%               0.4419                0.4715                0.4398
# max               0.4923                0.4998                0.4898
